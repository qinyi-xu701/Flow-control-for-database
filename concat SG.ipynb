# %%
import pandas as pd
import os
import numpy as np
import glob
from pathlib import Path
from datetime import datetime as dt

# %%
home = Path.home()
today = dt.today()
today = today.strftime("%Y%m%d")

# %%
target = Path(home, 'HP Inc','GPSTW SOP - 2021 日新','Project team','Single shortage','test')
targetList = [str(x) for x in target.glob("*xls")]
# PNFVPath = Path(home, 'HP Inc','GPSTW SOP - 2021 日新', 'PN FV description mapping table_ALL.xlsx')
# ExternalReportFolder = Path(home, 'HP Inc','GPSTW SOP - 2021 日新','Project team','External test destination', 'zzz')
# ExternalReport = [f for f in glob.glob(str(Path(ExternalReportFolder, today + '*')))]
# ExternalReport

# %%
SG_files = []
for SG_file in targetList:
    SG = pd.read_excel(SG_file)
    SG_files.append(SG)
SG_all = pd.concat(SG_files)

# %%
SG_all
# Out:
#    Commodity  Single Shortage QTY      ODM       Series       HP PN  \
# 0     USB IC             283000.0  Quanta     S400/S600  L97612-001
# 1     USB IC               3000.0    CQIEC       Tablet  939207-001
# 2     USB IC               2100.0    CQIEC         400s  L37400-001
# 3     USB IC              35585.0    CQIEC      Probook  L97612-001
# 4     USB IC                947.0    WHFXN  Workstation  L55496-001
# ..       ...                  ...      ...          ...         ...
# 10       CPU                 21.0    WHFXN  Workstation  L76950-001
# 11       CPU                  1.0    WHFXN  Workstation  L96953-001
# 12       CPU                 34.0    WHFXN  Workstation  L96955-001
# 13       CPU                 15.0    WHFXN  Workstation  L96958-001
# 14       CPU                  9.0    WHFXN  Workstation  M11272-001
#
#     Prev_Single Shortage QTY Category Procurement type Remark  \
# 0                   283000.0      BNB              B/S    NaN
# 1                        0.0      BNB              B/S    NaN
# 2                        0.0      BNB              B/S    NaN
# 3                    33000.0      BNB              B/S    NaN
# 4                      928.0      BDT              B/S    NaN
# ..                       ...      ...              ...    ...
# 10                      21.0      BDT              B/S    NaN
# 11                       1.0      BDT              B/S    NaN
# 12                      34.0      BDT              B/S    NaN
# 13                      15.0      BDT              B/S    NaN
# 14                       9.0      BDT              B/S    NaN
#
#    LastSGreportDate reportDate                               Descr  \
# 0        2022-04-12 2022-04-12          CYPD6127-48LQXI/CP10033BTT
# 1        2022-04-12 2022-04-12                    CYPD4226-40LQXIT
# 2        2022-04-12 2022-04-12                    CYPD5126-40LQXIT
# 3        2022-04-12 2022-04-12          CYPD6127-48LQXI/CP10033BTT
# 4        2022-04-12 2022-04-12                    CYPD4225-40LQXIT
# ..              ...        ...                                 ...
# 10       2022-11-08 2022-11-09    WS INTEL CASCADELAKE XEON W-2265
# 11       2022-11-08 2022-11-09  WS INTEL CASCADELAKE-SP XEON 6258R
# 12       2022-11-08 2022-11-09  WS INTEL CASCADELAKE-SP XEON 6246R
# 13       2022-11-08 2022-11-09  WS INTEL CASCADELAKE-SP XEON 6238R
# 14       2022-11-08 2022-11-09  WS INTEL CASCADELAKE-SP XEON 8260L
#
#                                                   ETA  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 10                  ETA 12/05*22 pcs/Intel/L76950-001
# 11                                  Working on upside
# 12  ETA 12/15*29 pcs/Intel/L96955-001 (Per RTF)\nE...
# 13  ETA 11/23*6 pcs/Intel/L96958-001\nETA 2023/1/2...
# 14  ETA 11/16*7 pcs/Intel/M11272-001\n\nWorking on...
#
#                     GPS Remark  incremental commit opportunity  HP_PN  \
# 0                          NaN                             NaN    NaN
# 1                          NaN                             NaN    NaN
# 2                          NaN                             NaN    NaN
# 3                          NaN                             NaN    NaN
# 4                          NaN                             NaN    NaN
# ..                         ...                             ...    ...
# 10  SG: Wait for CM's pull in                              NaN    NaN
# 11  SG: Wait for CM's pull in                              NaN    NaN
# 12  SG: Wait for CM's pull in                              NaN    NaN
# 13  SG: Wait for CM's pull in                              NaN    NaN
# 14  SG: Wait for CM's pull in                              NaN    NaN
#
#         CPU family Unnamed: 14
# 0              NaN         NaN
# 1              NaN         NaN
# 2              NaN         NaN
# 3              NaN         NaN
# 4              NaN         NaN
# ..             ...         ...
# 10    Cascade LAKE         NaN
# 11  CASCADELAKE-SP         NaN
# 12  CASCADELAKE-SP         NaN
# 13  CASCADELAKE-SP         NaN
# 14  CASCADELAKE-SP         NaN
#
# [2332 rows x 18 columns]

# %%
glob.glob(str(target))
# Out:
# ['C:\\Users\\lulo\\HP Inc\\GPSTW SOP - 2021 日新\\Project team\\Single shortage\\test']

# %%
targetList = [str(x) for x in target.glob("*xlsx")]
targetList
# Out:
# []

# %%
SG_all.to_excel(Path(home, 'Desktop', 'SG_all.xls'), index=False)
