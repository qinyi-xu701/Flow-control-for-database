# %%
import datetime
import os
import win32com.client
from pathlib import Path
import re

# %%
path = os.path.expanduser(os.path.join('~', 'HP Inc','GPSTW SOP - 2021 日新','Project team','Upload folder ( for buyer update )'))

# %%
today = datetime.date.today()
outlook = win32com.client.Dispatch("Outlook.Application").GetNamespace("MAPI")

outlook.Session.Accounts.Item(2)
#.GetNamespace("MAPI")
# Out:
# <COMObject Item>

# %%
item = outlook.Folders.Item(1)

# %%
inbox = item.Folders['inbox']
project_folder = inbox.Folders['Newcomen']
target_folder = project_folder.Folders['Processed_Data']
messages = target_folder.Items

# %%
def saveattachemnts(regex = '<(\d{4}-\d{2}-\d{2}) processed data>\[\'\d{8}_[&a-zA-Z ]+_[&a-zA-Z ]+_.*'):
    #regex = '<(\d{4}-\d{2}-\d{2}) processed data>\[\'\d{8}_[a-zA-Z]+_[a-zA-Z]+_.*'
    for message in messages:
        # if message.Subject == subject and message.Unread or message.Senton.date() == today:
        #assert re.match(regex, message.Subject)
        if re.match(regex, message.Subject) and message.Unread or message.Senton.date() == today:
            # body_content = message.body
            attachments = message.Attachments
            attachment = attachments.Item(1)
            for attachment in message.Attachments:
                if '_FD.xlsx' in str(attachment):
                    try:
                        attachment.SaveAsFile(os.path.join(path, 'FD_today', str(attachment)))
                    except Exception as e:
                        print(attachment)
                        print(e)
                    if re.match(regex, message.Subject) and message.Unread:
                        message.Unread = False
                    continue
                elif '_Shortage.xlsx' in str(attachment):
                    try: 
                        attachment.SaveAsFile(os.path.join(path, 'shortage_today', str(attachment)))
                    except Exception as e:
                        print(attachment)
                        print(e)
                    if re.match(regex, message.Subject) and message.Unread:
                        message.Unread = False
                    continue
                elif '_PNbasedDetail.xlsx' in str(attachment):
                    try:
                        attachment.SaveAsFile(os.path.join(path, 'PNbasedDetail_today', str(attachment)))
                    except Exception as e:
                        print(attachment)
                        print(e)
                    if re.match(regex, message.Subject) and message.Unread:
                        message.Unread = False
                    continue
                else:
                    pass
                #break
        else:
            print(message)

# %%
saveattachemnts()
# Out:
# <2022-10-20 processed data>['20221006_WEBCAM_CQQCI_ChouSaly(GPSTW)'];['20221006_WEBCAM_CQIEC_ChouSaly(GPSTW)']
# <2022-10-20 processed data>['20221005_WEBCAM_CQIEC_ChouSaly(GPSTW)'];['20221005_WEBCAM_CQQCI_ChouSaly(GPSTW)']
# <2022-10-20 processed data>['20221004_WEBCAM_CQQCI_ChouSaly(GPSTW)']
# <2022-10-20 processed data>['20221003_WEBCAM_CQQCI_ChouSaly(GPSTW)']
# <2022-10-20 processed data>['20221013_CONNECTOR_CQIEC_LiangLavinia_SMT'];['20221013_CONNECTOR_CQWIS_LiangLavinia'];['20221013_CONNECTOR_CQIEC_LiangLavinia_FA'];['20221013_CONNECTOR_CQQCI_LiangLavinia']
# <2022-10-20 processed data>['20221012_CONNECTOR_CQIEC_LiangLavinia_SMT'];['20221012_CONNECTOR_CQWIS_LiangLavinia'];['20221012_CONNECTOR_CQIEC_LiangLavinia_FA'];['20221012_CONNECTOR_CQQCI_LiangLavinia']
# <2022-10-20 processed data>['20221011_CONNECTOR_CQWIS_LiangLavinia'];['20221011_CONNECTOR_CQIEC_LiangLavinia_SMT'];['20221011_CONNECTOR_CQIEC_LiangLavinia_FA'];['20221011_CONNECTOR_CQQCI_LiangLavinia']
# <2022-10-20 processed data>['20220930_CONNECTOR_CQIEC_LiangLavinia_SMT'];['20220930_CONNECTOR_CQQCI_LiangLavinia'];['20220930_CONNECTOR_CEI_LiangLavinia_SMT'];['20220930_CONNECTOR_CQIEC_LiangLavinia_FA'];['20220930_CONNECTOR_CEI_LiangLavinia_FA'];['202209
# <2022-10-20 processed data>['20220929_CONNECTOR_CQIEC_LiangLavinia_FA'];['20220929_CONNECTOR_CQQCI_LiangLavinia'];['20220929_CONNECTOR_CQIEC_LiangLavinia_SMT'];['20220929_CONNECTOR_CQWIS_LiangLavinia']
# <2022-10-20 processed data>['20220928_CONNECTOR_CQWIS_LiangLavinia'];['20220928_CONNECTOR_CQIEC_LiangLavinia_FA'];['20220928_CONNECTOR_CQQCI_LiangLavinia'];['20220928_CONNECTOR_CQIEC_LiangLavinia_SMT']
# <2022-10-20 processed data>['20220927_CONNECTOR_CQQCI_LiangLavinia'];['20220927_CONNECTOR_CQWIS_LiangLavinia'];['20220927_CONNECTOR_CQIEC_LiangLavinia_FA'];['20220927_CONNECTOR_CQIEC_LiangLavinia_SMT']
# <2022-10-20 processed data>['20220926_CONNECTOR_CQQCI_LiangLavinia'];['20220926_CONNECTOR_CQIEC_LiangLavinia_SMT'];['20220926_CONNECTOR_CQIEC_LiangLavinia_FA']
# <2022-10-20 processed data>['20220923_CONNECTOR_CQIEC_LiangLavinia_FA'];['20220923_CONNECTOR_CQQCI_LiangLavinia'];['20220923_CONNECTOR_CQIEC_LiangLavinia_SMT']
# <2022-10-20 processed data>['20220922_CONNECTOR_CQIEC_LiangLavinia_SMT'];['20220922_CONNECTOR_CEI_LiangLavinia_SMT'];['20220922_CONNECTOR_CQIEC_LiangLavinia_FA'];['20220922_CONNECTOR_CQQCI_LiangLavinia']
# <2022-10-20 processed data>['20220921_CONNECTOR_CQIEC_LiangLavinia_FA'];['20220921_CONNECTOR_CQQCI_LiangLavinia'];['20220921_CONNECTOR_CQIEC_LiangLavinia_SMT']
# <2022-10-20 processed data>['20220920_CONNECTOR_CQIEC_LiangLavinia_FA'];['20220920_CONNECTOR_CQQCI_LiangLavinia'];['20220920_CONNECTOR_CEI_LiangLavinia_FA'];['20220920_CONNECTOR_CQIEC_LiangLavinia_SMT'];['20220920_CONNECTOR_CEI_LiangLavinia_SMT']
# <2022-10-20 processed data>['20220919_CONNECTOR_CEI_LiangLavinia_SMT'];['20220919_CONNECTOR_CQQCI_LiangLavinia'];['20220919_CONNECTOR_CEI_LiangLavinia_FA'];['20220919_CONNECTOR_CQIEC_LiangLavinia_SMT'];['20220919_CONNECTOR_CQIEC_LiangLavinia_FA']
# <2022-10-19 processed data>['20221005_SSS_TWIEC_LaiShirley'];['20221005_SSS_CEI_LaiShirley']
# <2022-10-19 processed data>['20221006_SSS_CEI_LaiShirley']
# <2022-10-19 processed data>['20221004_SSS_CEI_LaiShirley'];['20221004_SSS_TWIEC_LaiShirley']
# <2022-10-19 processed data>['20221003_SSS_TWIEC_LaiShirley'];['20221003_SSS_CEI_LaiShirley']
# <2022-10-19 processed data>['20221007_SSS_CEI_LaiShirley']
# <2022-10-19 processed data>['20221013_BATTERY_CQQCI_ChangEunice']
# <2022-10-19 processed data>['20220922_BATTERY_CEI_ChangEunice']
# <2022-10-19 processed data>['20221006_BATTERY_CQQCI_ChangEunice']
# <2022-10-19 processed data>['20221004_BATTERY_CQQCI_ChangEunice'];['20221004_BATTERY_CEI_ChangEunice']
# <2022-10-19 processed data>['20221003_BATTERY_CEI_ChangEunice'];['20221003_BATTERY_CQQCI_ChangEunice']
# <2022-10-19 processed data>['20220930_POWERCORDS_CQWIS_ChaoAngie(GPS)']
# <2022-10-19 processed data>['20220929_POWERCORDS_CQWIS_ChaoAngie(GPS)']
# <2022-10-19 processed data>['20220921_POWERCORDS_CQWIS_ChaoAngie(GPS)']
# <2022-10-19 processed data>['20221011_POWERCORDS_CQWIS_ChaoAngie(GPS)']
# <2022-10-19 processed data>['20221013_POWERCORDS_CQWIS_ChaoAngie(GPS)']
# <2022-10-19 processed data>['20220922_POWERCORDS_CQWIS_ChaoAngie(GPS)']
# <2022-10-19 processed data>['20220926_POWERCORDS_CQWIS_ChaoAngie(GPS)']
# <2022-10-19 processed data>['20220927_POWERCORDS_CQWIS_ChaoAngie(GPS)']
# <2022-10-19 processed data>['20220928_POWERCORDS_CQWIS_ZhaoGinger(CW)']
# <2022-10-19 processed data>['20220923_POWERCORDS_CQWIS_ChaoAngie(GPS)']
# <2022-10-19 processed data>['20221012_POWERCORDS_CQWIS_ChaoAngie(GPS)']
# <2022-10-19 processed data>['20220920_POWERCORDS_CQWIS_ChaoAngie(GPS)']
# <2022-10-19 processed data>['20221006_CPU_CQQCI_Karen'];['20221006_CPU_CQIEC_Karen']
# <2022-10-19 processed data>['20221005_CPU_WHFXN_Karen']
# <2022-10-18 processed data>['20221003_CPU_CQIEC_Karen'];['20221003_CPU_CQQCI_Karen'];['20221003_CPU_WHFXN_Karen']
# <2022-10-19 processed data>['20221004_CPU_CQIEC_Karen'];['20221004_CPU_WHFXN_Karen'];['20221004_CPU_CQQCI_Karen']
# <2022-10-18 processed data>['20221006_SSS_CQIEC_ChenVera'];['20221006_SSS_TWIEC_ChenVera']
# <2022-10-18 processed data>['20221007_SSS_CQIEC_ChenVera'];['20221007_SSS_CQWIS_ChenVera'];['20221007_SSS_TWIEC_ChenVera']
# <2022-10-18 processed data>['20221005_SSS_CQIEC_ChenVera'];['20221005_SSS_CQQCI_ChenVera'];['20221005_SSS_TWIEC_ChenVera']
# <2022-10-18 processed data>['20221004_SSS_TWIEC_ChenVera'];['20221004_SSS_CQIEC_ChenVera'];['20221004_SSS_CQQCI_ChenVera']
# <2022-10-18 processed data>['20221003_SSS_CQQCI_ChenVera'];['20221003_SSS_CQIEC_ChenVera'];['20221003_SSS_TWIEC_ChenVera']
# <2022-10-18 processed data>['20221006_LCD_CQIEC_LiLori'];['20221006_LCD_CEI_LiLori']
# <2022-10-18 processed data>['20221004_LCD_CQIEC_LiLori'];['20221004_LCD_CEI_LiLori']
# <2022-10-18 processed data>['20221003_LCD_CEI_LiLori'];['20221003_LCD_CQIEC_LiLori']
# <2022-10-18 processed data>['20221007_USBIC_CQIEC_WangAlice(GPSTaiwan)'];['20221007_USBIC_CQQCI_WangAlice(GPSTaiwan)'];['20221007_USBIC_CQWIS_WangAlice(GPSTaiwan)'];['20221007_USBIC_CEI_WangAlice(GPSTaiwan)'];['20221007_USBIC_WHFXN_WangAlice(GPSTaiwan)']
# <2022-10-18 processed data>['20221006_USBIC_CQQCI_WangAlice(GPSTaiwan)'];['20221006_USBIC_WHFXN_WangAlice(GPSTaiwan)'];['20221006_USBIC_CQIEC_WangAlice(GPSTaiwan)'];['20221006_USBIC_CQWIS_WangAlice(GPSTaiwan)'];['20221006_USBIC_CEI_WangAlice(GPSTaiwan)']
# <2022-10-18 processed data>['20221005_USBIC_CQQCI_WangAlice(GPSTaiwan)'];['20221005_USBIC_WHFXN_WangAlice(GPSTaiwan)'];['20221005_USBIC_CQIEC_WangAlice(GPSTaiwan)'];['20221005_USBIC_CQWIS_WangAlice(GPSTaiwan)'];['20221005_USBIC_CEI_WangAlice(GPSTaiwan)']
# <2022-10-18 processed data>['20221003_USBIC_CQWIS_WangAlice(GPSTaiwan)'];['20221003_USBIC_WHFXN_WangAlice(GPSTaiwan)'];['20221003_USBIC_CQIEC_WangAlice(GPSTaiwan)'];['20221003_USBIC_CEI_WangAlice(GPSTaiwan)'];['20221003_USBIC_CQQCI_WangAlice(GPSTaiwan)']
# <2022-10-18 processed data>['20221004_USBIC_CEI_WangAlice(GPSTaiwan)'];['20221004_USBIC_CQIEC_WangAlice(GPSTaiwan)'];['20221004_USBIC_CQWIS_WangAlice(GPSTaiwan)'];['20221004_USBIC_CQQCI_WangAlice(GPSTaiwan)'];['20221004_USBIC_WHFXN_WangAlice(GPSTaiwan)']
# <2022-10-18 processed data>['20221004_USBIC_CQIEC_WangAlice(GPSTaiwan)']
# <2022-10-18 processed data>['20221004_USBIC_CEI_WangAlice(GPSTaiwan)']
# <2022-10-18 processed data>['20221003_USBIC_WHFXN_WangAlice(GPSTaiwan)']
# <2022-10-18 processed data>['20221003_USBIC_CQWIS_WangAlice(GPSTaiwan)']
# <2022-10-18 processed data>['20221003_USBIC_CQQCI_WangAlice(GPSTaiwan)']
# <2022-10-18 processed data>['20221003_USBIC_CQIEC_WangAlice(GPSTaiwan)']
# <2022-10-18 processed data>['20221003_USBIC_CEI_WangAlice(GPSTaiwan)']
# <2022-10-18 processed data>['20221006_LCD_CEI_WangYu-Ting'];['20221006_LCD_CQIEC_WangYu-Ting'];['20221006_LCD_CQQCI_WangYu-Ting']
# <2022-10-18 processed data>['20221004_LCD_CEI_WangYu-Ting'];['20221004_LCD_CQQCI_WangYu-Ting']
# <2022-10-18 processed data>['20221003_LCD_CQQCI_WangYu-Ting'];['20221003_LCD_CEI_WangYu-Ting']
# <2022-10-18 processed data>['20221007_AC ADAPTOR_WHFXN_L5_HsiehAngela'];['20221007_AC ADAPTOR_TWIEC_HsiehAngela'];['20221007_AC ADAPTOR_CQWIS_HsiehAngela'];['20221007_AC ADAPTOR_CQIEC_HsiehAngela'];['20221007_AC ADAPTOR_CQQCI_HsiehAngela']
# <2022-10-18 processed data>['20221006_AC ADAPTOR_CQQCI_HsiehAngela'];['20221006_AC ADAPTOR_FLH_HsiehAngela'];['20221006_AC ADAPTOR_CQWIS_HsiehAngela'];['20221006_AC ADAPTOR_TWIEC_HsiehAngela'];['20221006_AC ADAPTOR_CQIEC_HsiehAngela'];['20221006_AC ADAPTO
# <2022-10-18 processed data>['20221005_AC ADAPTOR_WHFXN_L5_HsiehAngela'];['20221005_AC ADAPTOR_CQQCI_HsiehAngela'];['20221005_AC ADAPTOR_CQWIS_HsiehAngela'];['20221005_AC ADAPTOR_CQIEC_HsiehAngela'];['20221005_AC ADAPTOR_FLH_HsiehAngela'];['20221005_AC ADA
# <2022-10-18 processed data>['20221004_AC ADAPTOR_CQWIS_HsiehAngela'];['20221004_AC ADAPTOR_WHFXN_L5_HsiehAngela'];['20221004_AC ADAPTOR_CQIEC_HsiehAngela'];['20221004_AC ADAPTOR_FLH_HsiehAngela'];['20221004_AC ADAPTOR_TWIEC_HsiehAngela'];['20221004_AC ADA
# <2022-10-18 processed data>['20221003_AC ADAPTOR_WHFXN_L5_HsiehAngela'];['20221003_AC ADAPTOR_CQIEC_HsiehAngela'];['20221003_AC ADAPTOR_FLH_HsiehAngela'];['20221003_AC ADAPTOR_CQWIS_HsiehAngela'];['20221003_AC ADAPTOR_CQQCI_HsiehAngela'];['20221003_AC ADA
# <2022-10-18 processed data>['20221006_AC ADAPTOR_CQWIS_ChenJosephine(GPS)'];['20221006_AC ADAPTOR_CQIEC_ChenJosephine(GPS)'];['20221006_AC ADAPTOR_CQQCI_ChenJosephine(GPS)']
# <2022-10-18 processed data>['20221007_CPU&CS_CQIEC_Ariel'];['20221007_CPU&CS_WHFXN_Ariel'];['20221007_CPU&CS_CEI_Ariel'];['20221007_CPU&CS_CQQCI_Ariel']
# <2022-10-18 processed data>['20221006_CPU&CS_CQQCI_Ariel'];['20221006_CPU&CS_CEI_Ariel'];['20221006_CPU&CS_WHFXN_Ariel']
# <2022-10-18 processed data>['20221005_CPU&CS_CEI_Ariel'];['20221005_CPU&CS_CQQCI_Ariel']
# <2022-10-18 processed data>['20221004_CPU&CS_CQQCI_Ariel'];['20221004_CPU&CS_CEI_Ariel'];['20221004_CPU&CS_WHFXN_Ariel'];['20221004_CPU&CS_CQIEC_Ariel']
# <2022-10-18 processed data>['20221003_CPU&CS_CEI_Ariel'];['20221003_CPU&CS_WHFXN_Ariel'];['20221003_CPU&CS_CQQCI_Ariel'];['20221003_CPU&CS_CQIEC_Ariel']
# <2022-10-18 processed data>['20221005_AC ADAPTOR_CQWIS_ChenJosephine(GPS)']
# <2022-10-18 processed data>['20221004_AC ADAPTOR_CQWIS_ChenJosephine(GPS)'];['20221004_AC ADAPTOR_CQIEC_ChenJosephine(GPS)'];['20221004_AC ADAPTOR_CEI_ChenJosephine(GPS)'];['20221004_AC ADAPTOR_CQQCI_ChenJosephine(GPS)']
# <2022-10-18 processed data>['20221003_AC ADAPTOR_CEI_ChenJosephine(GPS)'];['20221003_AC ADAPTOR_CQWIS_ChenJosephine(GPS)'];['20221003_AC ADAPTOR_CQIEC_ChenJosephine(GPS)'];['20221003_AC ADAPTOR_CQQCI_ChenJosephine(GPS)']
# <2022-10-18 processed data>['20221007_CONNECTOR_CQWIS_LiangLavinia'];['20221007_CONNECTOR_CQQCI_LiangLavinia'];['20221007_CONNECTOR_CQIEC_LiangLavinia_FA'];['20221007_CONNECTOR_CQIEC_LiangLavinia_SMT'];['20221007_CONNECTOR_CEI_LiangLavinia_FA']
# <2022-10-18 processed data>['20221006_CONNECTOR_CQIEC_LiangLavinia_FA'];['20221006_CONNECTOR_CEI_LiangLavinia_FA'];['20221006_CONNECTOR_CQWIS_LiangLavinia'];['20221006_CONNECTOR_CQIEC_LiangLavinia_SMT'];['20221006_CONNECTOR_CQQCI_LiangLavinia']
# <2022-10-18 processed data>['20221005_CONNECTOR_CQIEC_LiangLavinia_FA'];['20221005_CONNECTOR_CEI_LiangLavinia_FA'];['20221005_CONNECTOR_CQIEC_LiangLavinia_SMT'];['20221005_CONNECTOR_CQQCI_LiangLavinia'];['20221005_CONNECTOR_CQWIS_LiangLavinia']
# <2022-10-18 processed data>['20221011_BATTERY_CQIEC_ChenVivian(GPS)']
# <2022-10-18 processed data>['20221007_CPU_CQIEC_Celine'];['20221007_CPU_CQQCI_Celine'];['20221007_CPU_WHFXN_Celine'];['20221007_CPU_CQWIS_Celine'];['20221007_CPU_CQPCQ_Celine']
# <2022-10-18 processed data>['20221006_CPU_SZBYD_Celine'];['20221006_CPU_CQIEC_Celine'];['20221006_CPU_CQWIS_Celine'];['20221006_CPU_CQPCQ_Celine'];['20221006_CPU_CQQCI_Celine'];['20221006_CPU_WHFXN_Celine']
# <2022-10-18 processed data>['20221005_CPU_SZBYD_Celine'];['20221005_CPU_CQIEC_Celine'];['20221005_CPU_CQQCI_Celine'];['20221005_CPU_WHFXN_Celine'];['20221005_CPU_CQPCQ_Celine'];['20221005_CPU_CQWIS_Celine']
# <2022-10-18 processed data>['20221004_CPU_CQWIS_Celine'];['20221004_CPU_CQPCQ_Celine'];['20221004_CPU_CQQCI_Celine'];['20221004_CPU_CQIEC_Celine'];['20221004_CPU_WHFXN_Celine'];['20221004_CPU_SZBYD_Celine']
# <2022-10-18 processed data>['20221003_CPU_CQWIS_Celine'];['20221003_CPU_SZBYD_Celine'];['20221003_CPU_CQQCI_Celine'];['20221003_CPU_CQPCQ_Celine'];['20221003_CPU_WHFXN_Celine'];['20221003_CPU_CQIEC_Celine']
# <2022-10-18 processed data>['20221004_CONNECTOR_CEI_LiangLavinia_SMT'];['20221004_CONNECTOR_CQIEC_LiangLavinia_SMT'];['20221004_CONNECTOR_CQWIS_LiangLavinia'];['20221004_CONNECTOR_CQQCI_LiangLavinia'];['20221004_CONNECTOR_CQIEC_LiangLavinia_FA'];['2022100
# <2022-10-18 processed data>['20221017_BATTERY_CQWIS_ChenVivian(GPS)']
# <2022-10-18 processed data>['20221007_CPU_CEI_Anny']
# <2022-10-18 processed data>['20221007_BATTERY_CQWIS_ChenVivian(GPS)']
# <2022-10-18 processed data>['20221006_CPU_CEI_Anny']
# <2022-10-18 processed data>['20221005_CPU_CEI_Anny']
# <2022-10-18 processed data>['20221003_CPU_CEI_Anny']
# <2022-10-18 processed data>['20221004_CPU_CEI_Anny']
# <2022-10-18 processed data>['20221003_CONNECTOR_CEI_LiangLavinia_SMT'];['20221003_CONNECTOR_CQIEC_LiangLavinia_FA'];['20221003_CONNECTOR_CEI_LiangLavinia_FA'];['20221003_CONNECTOR_CQQCI_LiangLavinia'];['20221003_CONNECTOR_CQWIS_LiangLavinia'];['20221003_C
# <2022-10-18 processed data>['20221007_CPU_CQWIS_Rocky'];['20221007_CPU_CQIEC_Rocky'];['20221007_CPU_CQQCI_Rocky']
# <2022-10-18 processed data>['20221006_CPU_CQWIS_Rocky'];['20221006_CPU_CQQCI_Rocky'];['20221006_CPU_CQIEC_Rocky']
# <2022-10-18 processed data>['20221007_POWERCORDS_WHFXN_ChaoAngie(GPS)'];['20221007_POWERCORDS_CQQCI_ChaoAngie(GPS)'];['20221007_POWERCORDS_CQWIS_ChaoAngie(GPS)'];['20221007_POWERCORDS_CQIEC_ChaoAngie(GPS)']
# <2022-10-18 processed data>['20221005_CPU_CQQCI_Rocky'];['20221005_CPU_CQIEC_Rocky'];['20221005_CPU_CQWIS_Rocky']
# <2022-10-18 processed data>['20221004_CPU_CQWIS_Rocky'];['20221004_CPU_CQQCI_Rocky'];['20221004_CPU_CQIEC_Rocky']
# <2022-10-18 processed data>['20221003_CPU_CQWIS_Rocky'];['20221003_CPU_CQIEC_Rocky'];['20221003_CPU_CQQCI_Rocky']
# <2022-10-18 processed data>['20221006_POWERCORDS_CQWIS_ChaoAngie(GPS)'];['20221006_POWERCORDS_CQQCI_ChaoAngie(GPS)'];['20221006_POWERCORDS_WHFXN_ChaoAngie(GPS)'];['20221006_POWERCORDS_CQIEC_ChaoAngie(GPS)']
# <2022-10-18 processed data>['20221005_POWERCORDS_CQQCI_ChaoAngie(GPS)'];['20221005_POWERCORDS_CQIEC_ChaoAngie(GPS)'];['20221005_POWERCORDS_CQWIS_ChaoAngie(GPS)'];['20221005_POWERCORDS_WHFXN_ChaoAngie(GPS)']
# <2022-10-18 processed data>['20221004_POWERCORDS_CQWIS_ChaoAngie(GPS)'];['20221004_POWERCORDS_WHFXN_ChaoAngie(GPS)'];['20221004_POWERCORDS_CQIEC_ChaoAngie(GPS)'];['20221004_POWERCORDS_CQQCI_ChaoAngie(GPS)']
# <2022-10-18 processed data>['20221003_POWERCORDS_CQQCI_ChaoAngie(GPS)'];['20221003_POWERCORDS_CQWIS_ChaoAngie(GPS)'];['20221003_POWERCORDS_WHFXN_ChaoAngie(GPS)'];['20221003_POWERCORDS_CQIEC_ChaoAngie(GPS)']
# <2022-10-18 processed data>['20221007_HDD_CEI_TangWinnie'];['20221007_HDD_FLH_TangWinnie'];['20221007_CardReader_CEI_TangWinnie']
# <2022-10-18 processed data>['20221006_HDD_FLH_TangWinnie'];['20221006_CardReader_CEI_TangWinnie'];['20221006_HDD_CEI_TangWinnie']
# <2022-10-18 processed data>['20221004_HDD_FLH_TangWinnie'];['20221004_HDD_CEI_TangWinnie'];['20221004_CardReader_CEI_TangWinnie']
# <2022-10-18 processed data>['20221005_HDD_FLH_TangWinnie'];['20221005_HDD_CEI_TangWinnie'];['20221005_CardReader_CEI_TangWinnie']
# <2022-10-18 processed data>['20221003_HDD_CEI_TangWinnie'];['20221003_CardReader_CEI_TangWinnie'];['20221003_HDD_FLH_TangWinnie']
# <2022-10-17 processed data>['20221007_TS_CQIEC_HsuDustin']
# <2022-10-17 processed data>['20221006_TS_CQIEC_HsuDustin']
# <2022-10-17 processed data>['20221005_TS_CQIEC_HsuDustin']
# <2022-10-17 processed data>['20221003_TS_CQIEC_HsuDustin']
# <2022-10-17 processed data>['20221004_TS_CQIEC_HsuDustin']
# <2022-10-17 processed data>['20221007_WLAN_CQIEC_ChengSpencer(GPS)'];['20221007_WLAN_CEI_ChengSpencer(GPS)'];['20221007_ThunderBT_CQIEC_ChengSpencer(GPS)'];['20221007_WLAN_CQWIS_ChengSpencer(GPS)'];['20221007_WLAN_CQPCQ_ChengSpencer(GPS)'];['20221007_WLAN
# <2022-10-17 processed data>['20221006_ThunderBT_CQIEC_ChengSpencer(GPS)'];['20221006_WLAN_CQWIS_ChengSpencer(GPS)'];['20221006_WLAN_WHFXN_ChengSpencer(GPS)'];['20221006_WLAN_CQQCI_ChengSpencer(GPS)'];['20221006_WLAN_CEI_ChengSpencer(GPS)'];['20221006_WLAN
# <2022-10-17 processed data>['20221005_WLAN_CEI_ChengSpencer(GPS)'];['20221005_WLAN_CQQCI_ChengSpencer(GPS)'];['20221005_WLAN_CQIEC_ChengSpencer(GPS)'];['20221005_WLAN_CQPCQ_ChengSpencer(GPS)'];['20221005_ThunderBT_CQIEC_ChengSpencer(GPS)'];['20221005_WLAN
# <2022-10-17 processed data>['20221004_WLAN_CEI_ChengSpencer(GPS)'];['20221004_WLAN_CQIEC_ChengSpencer(GPS)'];['20221004_WLAN_CQWIS_ChengSpencer(GPS)'];['20221004_WLAN_CQQCI_ChengSpencer(GPS)'];['20221004_ThunderBT_CQIEC_ChengSpencer(GPS)'];['20221004_WLAN
# <2022-10-17 processed data>['20221003_WLAN_CQQCI_ChengSpencer(GPS)'];['20221003_WLAN_CEI_ChengSpencer(GPS)'];['20221003_WLAN_CQIEC_ChengSpencer(GPS)'];['20221003_WLAN_CQPCQ_ChengSpencer(GPS)'];['20221003_ThunderBT_CQIEC_ChengSpencer(GPS)'];['20221003_WLAN
# <2022-10-17 processed data>['20221007_POWERCORDS_CEI_ZhaoGinger(CW)'];['20221007_POWERCORDS_CQQCI_ZhaoGinger(CW)'];['20221007_POWERCORDS_CQIEC_ZhaoGinger(CW)'];['20221007_POWERCORDS_CQPCQ_ZhaoGinger(CW)'];['20221007_POWERCORDS_TWIEC_ZhaoGinger(CW)']
# <2022-10-17 processed data>['20221006_POWERCORDS_CEI_ZhaoGinger(CW)'];['20221006_POWERCORDS_CQIEC_ZhaoGinger(CW)'];['20221006_POWERCORDS_CQQCI_ZhaoGinger(CW)'];['20221006_POWERCORDS_CQPCQ_ZhaoGinger(CW)'];['20221006_POWERCORDS_TWIEC_ZhaoGinger(CW)']
# <2022-10-17 processed data>['20221005_POWERCORDS_CQPCQ_ZhaoGinger(CW)'];['20221005_POWERCORDS_CQQCI_ZhaoGinger(CW)'];['20221005_POWERCORDS_TWIEC_ZhaoGinger(CW)'];['20221005_POWERCORDS_CEI_ZhaoGinger(CW)'];['20221005_POWERCORDS_CQIEC_ZhaoGinger(CW)']
# <2022-10-17 processed data>['20221005_PSU_WHFXN_LeeLydia(GPSTaiwan)'];['20221005_PSU_WHFXN_L5_LeeLydia(GPSTaiwan)']
# <2022-10-17 processed data>['20221004_PSU_WHFXN_L5_LeeLydia(GPSTaiwan)'];['20221004_PSU_WHFXN_LeeLydia(GPSTaiwan)']
# <2022-10-17 processed data>['20221003_PSU_WHFXN_LeeLydia(GPSTaiwan)'];['20221003_PSU_WHFXN_L5_LeeLydia(GPSTaiwan)']
# <2022-10-17 processed data>['20221004_POWERCORDS_CEI_ZhaoGinger(CW)'];['20221004_POWERCORDS_CQQCI_ZhaoGinger(CW)'];['20221004_POWERCORDS_TWIEC_ZhaoGinger(CW)'];['20221004_POWERCORDS_CQPCQ_ZhaoGinger(CW)'];['20221004_POWERCORDS_CQIEC_ZhaoGinger(CW) (2)']
# <2022-10-17 processed data>['20221003_POWERCORDS_CQIEC_ZhaoGinger(CW)'];['20221003_POWERCORDS_TWIEC_ZhaoGinger(CW)'];['20221003_POWERCORDS_CQPCQ_ZhaoGinger(CW)'];['20221003_POWERCORDS_CQQCI_ZhaoGinger(CW)'];['20221003_POWERCORDS_CEI_ZhaoGinger(CW)']
# <2022-10-17 processed data>['20221003_RAM_WHFXN_JhangEmily'];['20221003_RAM_CQPCQ_JhangEmily'];['20221003_RAM_CQQCI_JhangEmil'];['20221003_RAM_TWIEC_JhangEmily']
# <2022-10-17 processed data>['20221004_RAM_WHFXN_JhangEmily'];['20221004_RAM_CQQCI_JhangEmily'];['20221004_RAM_CQPCQ_JhangEmily'];['20221004_RAM_TWIEC_JhangEmily']
# <2022-10-17 processed data>['20221005_RAM_CQPCQ_JhangEmily'];['20221005_RAM_CQQCI_JhangEmily'];['20221005_RAM_WHFXN_JhangEmily'];['20221005_RAM_CQIEC_JhangEmily_FA'];['20221005_RAM_CQIEC_JhangEmily'];['20221005_RAM_TWIEC_JhangEmily']
# <2022-10-17 processed data>['20221006_RAM_CQPCQ_JhangEmily'];['20221006_RAM_WHFXN_JhangEmily'];['20221006_RAM_TWIEC_JhangEmily']
# <2022-10-17 processed data>['20221007_VRAM_CEI_JhangEmily']
# <2022-10-17 processed data>['20221007_RAM_CQIEC_JhangEmily'];['20221007_RAM_CQIEC_JhangEmily_FA'];['20221007_RAM_WHFXN_JhangEmily'];['20221007_RAM_CQPCQ_JhangEmily']
# <2022-10-15 processed data>['20221006_LCD_CQQCI_FerngApple'];['20221006_LCD_CQIEC_FerngApple']
# <2022-10-14 processed data>['20221013_WLAN_CQQCI_ChengSpencer(GPS)'];['20221013_WLAN_CEI_ChengSpencer(GPS)']
# <2022-10-12 processed data>['20221012_TS_CQIEC_HsuDustin']
# <2022-10-11 processed data>['20221011_TS_CQIEC_HsuDustin']
# <2022-10-06 processed data>['20221006_ThunderBT_CQIEC_ChengSpencer(GPS)']
# <2022-10-05 processed data>['20221005_ThunderBT_CQIEC_ChengSpencer(GPS)']
# <2022-10-05 processed data>['20221005_TS_CQIEC_HsuDustin']
# <2022-10-03 processed data>['20221003_ThunderBT_CQIEC_ChengSpencer(GPS)']
# <2022-09-20 processed data>['20220920_TS_CQIEC_HsuDustin']
# <2022-10-20 processed data>['20221003_CPU&CS_CQWIS_Abby'];['20221003_CPU&CS_CQPCQ_Abby'];['20221003_CPU&CS_CQIEC_Abby'];['20221003_CPU&CS_WHFXN_Abby'];['20221003_CPU&CS_CQQCI_Abby']
# <2022-10-20 processed data>['20221004_CPU&CS_CQPCQ_Abby'];['20221004_CPU&CS_CQQCI_Abby'];['20221004_CPU&CS_CQWIS_Abby'];['20221004_CPU&CS_CQIEC_Abby'];['20221004_CPU&CS_WHFXN_Abby']
# <2022-10-20 processed data>['20221005_CPU&CS_CQWIS_Abby'];['20221005_CPU&CS_CQQCI_Abby'];['20221005_CPU&CS_WHFXN_Abby'];['20221005_CPU&CS_CQIEC_Abby'];['20221005_CPU&CS_CQPCQ_Abby']
# <2022-10-20 processed data>['20221007_CPU&CS_CQPCQ_Abby'];['20221007_CPU&CS_CQQCI_Abby'];['20221007_CPU&CS_CQWIS_Abby'];['20221007_CPU&CS_CQIEC_Abby'];['20221007_CPU&CS_WHFXN_Abby']
# <2022-10-20 processed data>['20221006_CPU&CS_CQWIS_Abby'];['20221006_CPU&CS_CQIEC_Abby'];['20221006_CPU&CS_WHFXN_Abby'];['20221006_CPU&CS_CQPCQ_Abby'];['20221006_CPU&CS_CQQCI_Abby']
# <2022-10-20 processed data>['20221003_TPM_WHFXN_LiSophia(GPSTW)'];['20221003_TPM_CQQCI_LiSophia(GPSTW)']
# <2022-10-20 processed data>['20221004_TPM_CQQCI_LiSophia(GPSTW)'];['20221004_TPM_WHFXN_LiSophia(GPSTW)']
# <2022-10-20 processed data>['20221005_TPM_CQQCI_LiSophia(GPSTW)'];['20221005_TPM_WHFXN_LiSophia(GPSTW)']
# <2022-10-20 processed data>['20221006_TPM_WHFXN_LiSophia(GPSTW)'];['20221006_TPM_CQQCI_LiSophia(GPSTW)']
# <2022-10-20 processed data>['20221007_TPM_CQQCI_LiSophia(GPSTW)'];['20221007_TPM_WHFXN_LiSophia(GPSTW)']
# <2022-10-20 processed data>['20221003_WS CPU_TWIEC_LiSophia(GPSTW)'];['20221003_WS CPU_WHFXN_LiSophia(GPSTW)']
# <2022-10-20 processed data>['20221004_WS CPU_WHFXN_LiSophia(GPSTW)'];['20221004_WS CPU_TWIEC_LiSophia(GPSTW)']
# <2022-10-20 processed data>['20221005_WS CPU_WHFXN_LiSophia(GPSTW)'];['20221005_WS CPU_TWIEC_LiSophia(GPSTW)']
# <2022-10-20 processed data>['20221006_WS CPU_TWIEC_LiSophia(GPSTW)'];['20221006_WS CPU_WHFXN_LiSophia(GPSTW)']
# <2022-10-20 processed data>['20221007_WS CPU_WHFXN_LiSophia(GPSTW)'];['20221007_WS CPU_TWIEC_LiSophia(GPSTW)']
# <2022-10-21 processed data>['20221007_WEBCAM_CQQCI_ChouSaly(GPSTW)']
# <2022-10-21 processed data>['20221005_LCD_CEI_WangYu-Ting']
# <2022-10-21 processed data>['20221007_GPU_CQIEC_Jennifer'];['20221007_GPU_CEI_Jennifer'];['20221007_GPU_CQQCI_Jennifer']
# <2022-10-21 processed data>['20221006_GPU_CQQCI_Jennifer'];['20221006_GPU_CEI_Jennifer'];['20221006_GPU_CQIEC_Jennifer']
# <2022-10-21 processed data>['20221005_GPU_CQIEC_Jennifer'];['20221005_GPU_CQQCI_Jennifer'];['20221005_GPU_CEI_Jennifer']
# <2022-10-21 processed data>['20221004_GPU_CQIEC_Jennifer'];['20221004_GPU_CQQCI_Jennifer'];['20221004_GPU_CEI_Jennifer']
# <2022-10-21 processed data>['20221003_GPU_CQIEC_Jennifer'];['20221003_GPU_CEI_Jennifer'];['20221003_GPU_CQQCI_Jennifer']
# <2022-10-21 processed data>['20221007_WEBCAM_CQIEC_LeeKylie']
# <2022-10-21 processed data>['20221006_WEBCAM_CQIEC_LeeKylie']
# <2022-10-21 processed data>['20221005_WEBCAM_CQIEC_LeeKylie']
# <2022-10-22 processed data>['20220919_CONNECTOR_CQIEC_LiangLavinia_FA'];['20220919_CONNECTOR_CEI_LiangLavinia_FA'];['20220919_CONNECTOR_CEI_LiangLavinia_SMT']
# <2022-10-22 processed data>['20220920_CONNECTOR_CEI_LiangLavinia_FA'];['20220920_CONNECTOR_CQIEC_LiangLavinia_FA'];['20220920_CONNECTOR_CEI_LiangLavinia_SMT']
# <2022-10-22 processed data>['20220921_CONNECTOR_CQIEC_LiangLavinia_FA']
# <2022-10-22 processed data>['20220922_CONNECTOR_CQIEC_LiangLavinia_SMT'];['20220922_CONNECTOR_CQIEC_LiangLavinia_FA'];['20220922_CONNECTOR_CEI_LiangLavinia_SMT']
# <2022-10-22 processed data>['20220923_CONNECTOR_CQIEC_LiangLavinia_FA']
# <2022-10-22 processed data>['20220926_CONNECTOR_CQIEC_LiangLavinia_FA']
# <2022-10-22 processed data>['20220927_CONNECTOR_CQIEC_LiangLavinia_FA'];['20220927_CONNECTOR_CQWIS_LiangLavinia']
# <2022-10-22 processed data>['20220928_CONNECTOR_CQIEC_LiangLavinia_FA']
# <2022-10-22 processed data>['20220929_CONNECTOR_CQIEC_LiangLavinia_FA']
# <2022-10-22 processed data>['20220930_CONNECTOR_CEI_LiangLavinia_SMT'];['20220930_CONNECTOR_CEI_LiangLavinia_FA'];['20220930_CONNECTOR_CQIEC_LiangLavinia_FA']
# <2022-10-22 processed data>['20221004_CONNECTOR_CQIEC_LiangLavinia_FA'];['20221004_CONNECTOR_CQQCI_LiangLavinia'];['20221004_CONNECTOR_CQIEC_LiangLavinia_SMT'];['20221004_CONNECTOR_CEI_LiangLavinia_SMT'];['20221004_CONNECTOR_CEI_LiangLavinia_FA']
# <2022-10-22 processed data>['20221005_CONNECTOR_CEI_LiangLavinia_FA'];['20221005_CONNECTOR_CQIEC_LiangLavinia_FA'];['20221005_CONNECTOR_CQWIS_LiangLavinia']
# <2022-10-22 processed data>['20221006_CONNECTOR_CQIEC_LiangLavinia_FA'];['20221006_CONNECTOR_CQIEC_LiangLavinia_SMT'];['20221006_CONNECTOR_CQWIS_LiangLavinia'];['20221006_CONNECTOR_CEI_LiangLavinia_FA']
# <2022-10-22 processed data>['20221007_CONNECTOR_CEI_LiangLavinia_FA'];['20221007_CONNECTOR_CQIEC_LiangLavinia_FA']
# <2022-10-22 processed data>['20221011_CONNECTOR_CQIEC_LiangLavinia_FA'];['20221011_CONNECTOR_CQIEC_LiangLavinia_SMT']
# <2022-10-22 processed data>['20221013_CONNECTOR_CQIEC_LiangLavinia_FA'];['20221013_CONNECTOR_CQIEC_LiangLavinia_SMT']
# <2022-10-22 processed data>['20221012_CONNECTOR_CQIEC_LiangLavinia_SMT'];['20221012_CONNECTOR_CQIEC_LiangLavinia_FA']
# <2022-10-22 processed data>['20221014_CONNECTOR_CQIEC_LiangLavinia_SMT'];['20221014_CONNECTOR_CQIEC_LiangLavinia_FA']
# <2022-10-22 processed data>['20221017_CONNECTOR_CQIEC_LiangLavinia_SMT']
# <2022-10-24 processed data>['20221005_SSS_TWIEC_LeeCynthia(GPSTW)'];['20221005_SSS_CQIEC_LeeCynthia(GPSTW)'];['20221005_SSS_CQQCI_LeeCynthia(GPSTW)']
# <2022-10-24 processed data>['20221004_SSS_TWIEC_LeeCynthia(GPSTW)']
# <2022-10-24 processed data>['20221003_SSS_TWIEC_LeeCynthia(GPSTW)']
# <2022-10-24 processed data>['20220926_SSS_WHFXN_LeeCynthia(GPSTW)'];['20220926_SSS_CQQCI_LeeCynthia(GPSTW)'];['20220926_SSS_CQWIS_LeeCynthia(GPSTW)'];['20220926_SSS_CQIEC_LeeCynthia(GPSTW)']
# <2022-10-24 processed data>['20220923_SSS_WHFXN_LeeCynthia(GPSTW)'];['20220923_SSS_CQIEC_LeeCynthia(GPSTW)'];['20220923_SSS_CQQCI_LeeCynthia(GPSTW)'];['20220923_SSS_CQWIS_LeeCynthia(GPSTW)']
# <2022-10-24 processed data>['20221007_SSS_CQIEC_LeeCynthia(GPSTW)'];['20221007_SSS_CQQCI_LeeCynthia(GPSTW)'];['20221007_SSS_WHFXN_LeeCynthia(GPSTW)'];['20221007_SSS_TWIEC_LeeCynthia(GPSTW)']
# <2022-10-24 processed data>['20221012_SSS_WHFXN_LeeCynthia(GPSTW)'];['20221012_SSS_CQWIS_LeeCynthia(GPSTW)'];['20221012_SSS_TWIEC_LeeCynthia(GPSTW)'];['20221012_SSS_CQIEC_LeeCynthia(GPSTW)'];['20221012_SSS_CQQCI_LeeCynthia(GPSTW)']
# <2022-10-24 processed data>['20221006_SSS_CQQCI_LeeCynthia(GPSTW)'];['20221006_SSS_CQIEC_LeeCynthia(GPSTW)'];['20221006_SSS_TWIEC_LeeCynthia(GPSTW)'];['20221006_SSS_WHFXN_LeeCynthia(GPSTW)']
# <2022-10-24 processed data>['20221014_AC ADAPTOR_FLH_HsiehAngela'];['20221014_AC ADAPTOR_CQIEC_HsiehAngela_update'];['20221014_AC ADAPTOR_CQQCI_HsiehAngela_update'];['20221014_AC ADAPTOR_WHFXN_L5_HsiehAngela'];['20221014_AC ADAPTOR_TWIEC_HsiehAngela'];['2
# 回收: <2022-10-24 processed data>['20221020_BATTERY_CQQCI_ChangEunice']
# <2022-10-24 processed data>['20221020_BATTERY_CQQCI_ChangEunice']
# <2022-10-24 processed data>['20221020_BATTERY_CQQCI_ChangEunice']
# <2022-10-24 processed data>['20221019_BATTERY_CQQCI_ChangEunice']
# <2022-10-24 processed data>['20221007_LanChip_CEI_LinSharon']
# <2022-10-24 processed data>['20221004_LCD_CEI_ChenJasmine'];['20221004_LCD_CQQCI_ChenJasmine'];['20221004_LCD_CQWIS_ChenJasmine'];['20221004_LCD_CQIEC_ChenJasmine']
# <2022-10-24 processed data>['20221003_LCD_CQQCI_ChenJasmine'];['20221003_LCD_CEI_ChenJasmine'];['20221003_LCD_CQIEC_ChenJasmine'];['20221003_LCD_CQWIS_ChenJasmine']
# <2022-10-24 processed data>['20221006_LCD_CQQCI_ChenJasmine'];['20221006_LCD_CQIEC_ChenJasmine_14'];['20221006_LCD_CQIEC_ChenJasmine']
# <2022-10-24 processed data>['20221006_LanChip_CQIEC_LinSharon'];['20221006_LanChip_CQQCI_LinSharon'];['20221006_LanChip_CEI_LinSharon']
# <2022-10-24 processed data>['20221004_LanChip_CQIEC_LinSharon'];['20221004_LanChip_CQQCI_LinSharon']
# <2022-10-24 processed data>['20221003_LanChip_CQQCI_LinSharon'];['20221003_LanChip_CQIEC_LinSharon']
# <2022-10-24 processed data>['20221007_RAM_CQWIS_WangWinson(CW)'];['20221007_RAM_CQIEC_WangWinson(CW)'];['20221007_RAM_WHFXN_WangWinson(CW)']
# <2022-10-24 processed data>['20221004_RAM_WHFXN_WangWinson(CW)'];['20221004_RAM_CQWIS_WangWinson(CW)'];['20221004_RAM_CQIEC_WangWinson(CW)']
# <2022-10-24 processed data>['20221006_RAM_CQIEC_WangWinson(CW)'];['20221006_RAM_WHFXN_WangWinson(CW)'];['20221006_RAM_TWIEC_WangWinson(CW)']
# <2022-10-24 processed data>['20221005_RAM_CQWIS_WangWinson(CW)'];['20221005_RAM_WHFXN_WangWinson(CW)'];['20221005_RAM_CQIEC_WangWinson(CW)']
# <2022-10-24 processed data>['20221003_RAM_WHFXN_WangWinson(CW)'];['20221003_RAM_CQWIS_WangWinson(CW)'];['20221003_RAM_CQIEC_WangWinson(CW)']
# <2022-10-24 processed data>['20221007_ODD_WHFXN_linsh']
# <2022-10-24 processed data>['20221006_ODD_WHFXN_linsh']
# <2022-10-24 processed data>['20220919_POWERCORDS_CQWIS_ChaoAngie(GPS)']
# <2022-10-24 processed data>['20221024_BATTERY_CQWIS_ChenVivian(GPS)']
# <2022-10-23 processed data>['20220921_WLAN_CQQCI_ChengSpencer(GPS)']
# <2022-10-23 processed data>['20220919_CPU_WHFXN_Celine']
